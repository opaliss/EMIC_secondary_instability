# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import wofz 
import scipy
from scipy.sparse import diags

# %%
# %matplotlib inline
import matplotlib
font = {'family' : 'sans-serif',
        'size'   : 14}

matplotlib.rc('font', **font)
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14)

# %%
fig, ax = plt.subplots(figsize=(6, 4))

alpha = np.linspace(0, 1.1, int(1e4))

ax.plot(alpha, 1+alpha, linewidth=4, color="tab:blue", label=r"$|\vec{V}_{De}|/|\vec{V}_{Dp}|$", alpha=0.7)
ax.plot(alpha, 4*alpha/(1+alpha), linewidth=4, color="tab:red", label=r"$|\vec{V}_{DHe^{+}}|/|\vec{V}_{Dp}|$", alpha=0.7)
ax.plot(alpha, 16*alpha/(1+alpha), linewidth=4, color="tab:green", label=r"$|\vec{V}_{DO^{+}}|/|\vec{V}_{Dp}|$", alpha=0.7)

ax.axvline(1, color="black", ls="--")
ax.axvline(1/4, color="black", ls="--")
ax.axvline(1/16, color="black", ls="--")



legend = ax.legend(ncols=1, fancybox=False, shadow=False,  loc="upper left")
legend.get_frame().set_alpha(0)

#ax.set_yscale("log")
ax.set_xscale("log")

ax.set_xlabel(r"$\omega_{0}/\Omega_{cp}$")

ax.set_xticks([1/16, 1/4,  1])
ax.set_xticklabels([r"$1/16$", r"$1/4$", r"$1$"])

ax.axvspan(1/22, 1/16, color='tab:green', alpha=0.1)
ax.axvspan(1/16, 1/4, color='tab:red', alpha=0.1)
ax.axvspan(1/4, 1, color='tab:purple', alpha=0.1)

ax.set_xlim(1/22, 1.1)
ax.set_ylim(1e-1, 10)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.grid(alpha=0.2)
plt.tight_layout()
plt.savefig("figures/estimates/drift_estimate_emic.png", dpi=400)
