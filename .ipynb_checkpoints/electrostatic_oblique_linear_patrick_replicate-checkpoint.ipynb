# %% [markdown]
# Aug 14th, 2025
#
#
# Author: Opal Issan (oissan@ucsd.edu)

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import wofz 
import scipy
import math
from QLT_equations.general_plasma_equations import Z_prime, I, Z

# %%
# %matplotlib inline
import matplotlib
font = {'family' : 'sans-serif',
        'size'   : 14}

matplotlib.rc('font', **font)
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14)

# %%
# normalization
# time is normalized to the electron cyclotron frequency
# space is normalized to electron inertial length d_e

# match the values in khazanov et al. The nonlinear coupling of electromagnetic ion cyclotron and lower hybrid

# cold electron density
ne = 1  # ne
# cold He+ density
nHe = 0  # ne
# cold O+ density
nO = 0.1 # ne
# hot proton density
npH = 0.1  # ne
# cold proton density
npC = 1 - npH - nO - nHe  # ne

# mass ratios
mp_me = 100  # dimensionless
mO_mp = 16  # dimensionless
mHe_mp = 4  # dimensionless

omega_pe = 2 # Omega_ce

# assume the plasma is isothermal Te=Tp=TO+=THe+
alpha_c_perp = np.sqrt(1e-4)  # d_e x Omega_ce
alpha_c_par = alpha_c_perp  # d_e x Omega_ce
alpha_p_par = alpha_c_perp / np.sqrt(mp_me)  # d_e x Omega_ce
alpha_He_par = alpha_c_perp / np.sqrt(mp_me * mHe_mp)  # de x Omega_ce
alpha_O_par = alpha_c_perp / np.sqrt(mp_me * mO_mp)  # de x Omega_ce


wLH = 1/np.sqrt(mp_me) # Omega_ce
rhoe = alpha_c_perp/np.sqrt(2) # de 

# relative drift is what matters
UDp = 1.63299 * alpha_p_par / np.sqrt(2)
UDO = -8.77876 * alpha_O_par / np.sqrt(2)
UDHe = 0. * alpha_He_par / np.sqrt(2)

# %% [markdown]
# # dispersion relation
#
# \begin{align*}
#     1 - \frac{\omega_{pe}^2}{\omega^2 }\frac{k_{\|}^2}{|\vec{k}|^2} + \frac{\omega_{pe}^2}{\Omega_{ce}^2}
#     = \sum_{s=\{He^{+}, O^{+}, p\}}\frac{\omega_{ps}^2}{\alpha_{\| s}^2 k_{\perp}^2}  Z' \left( \frac{\omega - k_{\perp} U_{x, Ds}}{\alpha_{\| s} |k_{\perp}|}\right).
# \end{align*}

# %%
def cold_electron_response(k_perp_, omega, omega_pe_, k_par_):
    return - (k_par_**2)/(k_par_**2 + k_perp_**2) * (omega_pe_**2)/(omega**2) + omega_pe_**2 * (k_perp_**2)/(k_par_**2 + k_perp_**2)

def ion_response(omega_pi_, alpha_i_, k_perp_, v_0_, n_, omega, k_par_):
    return n_ * (omega_pi_ ** 2) / (alpha_i_ ** 2) / (k_perp_**2) * Z_prime(z=(omega - k_perp_ * v_0_) / (alpha_i_ * np.sqrt(k_perp_**2 + k_par_**2)))

# %%
def disp_k_(k_perp,
            k_par,
            npC_=npC,
            nO_=nO,
            nHe_=nHe,
            omega_pe_=omega_pe,
            mp_me_=mp_me,
            mO_mp_=mO_mp,
            mHe_mp_=mHe_mp,
            VDp_=UDp,
            VDHe_=UDHe,
            VDO_=UDO,
            alpha_p_par_=alpha_p_par,
            alpha_O_par_=alpha_O_par,
            alpha_He_par_=alpha_He_par):
    return lambda omega: 1 + cold_electron_response(k_perp_=k_perp, omega=omega, omega_pe_=omega_pe_, k_par_=k_par) \
                         - ion_response(omega_pi_=omega_pe_ / np.sqrt(mp_me_), n_=npC_, alpha_i_=alpha_p_par_,
                                        k_perp_=k_perp, v_0_=VDp_, omega=omega, k_par_=k_par) \
                         - ion_response(omega_pi_=omega_pe_ / np.sqrt(mp_me_ * mO_mp_), n_=nO_,
                                        alpha_i_=alpha_O_par_, k_perp_=k_perp, v_0_=VDO_, omega=omega, k_par_=k_par) \
                         - ion_response(omega_pi_=omega_pe_ / np.sqrt(mp_me_ * mHe_mp_), n_=nHe_,
                                        alpha_i_=alpha_He_par_, k_perp_=k_perp, v_0_=VDHe_, omega=omega, k_par_=k_par)

# %% [markdown]
# # Ion-ion current-driven instability
# \begin{equation*}
#     k_{\perp} \approx
# \frac{\omega_{\mathrm{LH}} \sqrt{c_{cp}}}{U_{x, DO+}}\qquad \mathrm{and} \qquad \omega_{r} = \left[1 - \frac{1}{2^{\frac{4}{3}}} \left[\frac{c_{O+}}{c_{cp}} \frac{m_{p}}{ m_{O+}} \right]^{\frac{1}{3}} \right] \omega_{\mathrm{LH}} \sqrt{c_{cp}}.
# \end{equation*}

# %%
k_perp =  np.sqrt(npC)*wLH/UDO# de
k_par = 0
omega_guess = -np.sqrt(npC) * (1 - 1/(2**(4/3)) * ((nO/npC / mO_mp)**(1/3))) * wLH  # Omega_ce


sol_approx = scipy.optimize.newton(disp_k_(k_perp=k_perp, k_par=k_par), omega_guess + 0.005j, tol=1e-16, 
                                   maxiter=10000, x1=omega_guess*0.99 + 1e-2j)
print(sol_approx)
print("omega_k + i gamma = ", sol_approx)
print("dispersion residual approx = ", abs(disp_k_(k_perp=k_perp, k_par=k_par)(sol_approx)))
# Out:
# /Users/oissan/PycharmProjects/EMIC_secondary_instability/QLT_equations/general_plasma_equations.py:19: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1j * np.sqrt(np.pi) * wofz(z)
# /opt/anaconda3/envs/rom/lib/python3.9/site-packages/scipy/optimize/_zeros_py.py:382: RuntimeWarning: invalid value encountered in scalar divide
#   p = (-q1 / q0 * p0 + p1) / (1 - q1 / q0)
# /var/folders/tt/hgb4_vc13z77x5wpt5lzk5j40000gn/T/ipykernel_19245/875342221.py:2: RuntimeWarning: invalid value encountered in scalar divide
#   return - (k_par_**2)/(k_par_**2 + k_perp_**2) * (omega_pe_**2)/(omega**2) + omega_pe_**2 * (k_perp_**2)/(k_par_**2 + k_perp_**2)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 6
#       2 k_par = 0
#       3 omega_guess = -np.sqrt(npC) * (1 - 1/(2**(4/3)) * ((nO/npC / mO_mp)**(1/3))) * wLH  # Omega_ce
# ----> 6 sol_approx = scipy.optimize.newton(disp_k_(k_perp=k_perp, k_par=k_par), omega_guess + 0.005j, tol=1e-16,
#       7                                    maxiter=10000, x1=omega_guess*0.99 + 1e-2j)
#       8 print(sol_approx)
#       9 print("omega_k + i gamma = ", sol_approx)
#
# File /opt/anaconda3/envs/rom/lib/python3.9/site-packages/scipy/optimize/_zeros_py.py:394, in newton(func, x0, fprime, args, tol, maxiter, fprime2, x1, rtol, full_output, disp)
#     391 if disp:
#     392     msg = ("Failed to converge after %d iterations, value is %s."
#     393            % (itr + 1, p))
# --> 394     raise RuntimeError(msg)
#     396 return _results_select(full_output, (p, funcalls, itr + 1, _ECONVERR), method)
#
# RuntimeError: Failed to converge after 10000 iterations, value is (nan+nanj).

# %%
k_perp_ii = np.linspace(0.5, 5, 20) * np.sqrt(npC) * wLH /UDO # d_e
k_par_ii =  np.abs(np.linspace(0, 5, 15) * np.sqrt(npC) * wLH /UDO) # d_e
sol_ii = np.zeros((len(k_perp_ii), len(k_par_ii)), dtype="complex128") * np.nan

# %%
for ii in range(len(k_perp_ii)):
    for jj in range(len(k_par_ii)):
        try:
            sol_ii[ii, jj] = scipy.optimize.newton(disp_k_(k_perp=k_perp_ii[ii], k_par=k_par_ii[jj]), 
                                                 omega_guess + 0.005j, tol=1e-16, maxiter=10000, x1=omega_guess*0.5 + 1e-2j)
            
            error = abs(disp_k_(k_perp=k_perp_ii[ii], k_par=k_par_ii[jj])(sol_ii[ii, jj]))
            print("dispersion residual = ", error)
            if error > 1e-10:
                sol_ii[ii, jj] = np.nan
        except:
            print("An exception occurred")
# Out:
# dispersion residual =  3.5244770403704717e-15
# dispersion residual =  1.783556063501567e-16
# dispersion residual =  7.15959415827548e-15
# dispersion residual =  1.9597063661901576e-14
# dispersion residual =  2.6714424748159613e-15
# dispersion residual =  1.7440476146601824e-14
# dispersion residual =  1.5252556975349592e-15
# dispersion residual =  5.7137516035214995e-15
# dispersion residual =  2.908126655786868e-16
# dispersion residual =  7.844696220416894e-15
# dispersion residual =  2.62158433622585e-15
# dispersion residual =  1.553011192655509e-15
# dispersion residual =  8.258135662045334e-14
# dispersion residual =  2.4486835005979777e-14
# dispersion residual =  4.1517851728915517e-13
# /var/folders/tt/hgb4_vc13z77x5wpt5lzk5j40000gn/T/ipykernel_19245/875342221.py:2: RuntimeWarning: invalid value encountered in scalar divide
#   return - (k_par_**2)/(k_par_**2 + k_perp_**2) * (omega_pe_**2)/(omega**2) + omega_pe_**2 * (k_perp_**2)/(k_par_**2 + k_perp_**2)
# An exception occurred
# dispersion residual =  4.323548382038069e-14
# dispersion residual =  4.409393573839426e-16
# dispersion residual =  1.9414507048510361e-16
# dispersion residual =  1.112610093035862e-15
# dispersion residual =  5.5714532073684504e-15
# dispersion residual =  2.856896860731607e-16
# dispersion residual =  1.0760706561918748e-15
# dispersion residual =  3.8510887403978013e-16
# dispersion residual =  9.28719851534012e-14
# dispersion residual =  8.929635154981253e-14
# dispersion residual =  1.6552712760715393e-14
# dispersion residual =  5.4129643419360464e-15
# dispersion residual =  6.857207542484363e-14
# dispersion residual =  8.135057639909225e-14
# An exception occurred
# dispersion residual =  1.9639967517479862e-14
# dispersion residual =  2.4883039621271026e-15
# dispersion residual =  1.2568112748230042e-15
# dispersion residual =  4.584991515571797e-16
# dispersion residual =  3.3416436735861753e-16
# dispersion residual =  1.2091909488402012e-15
# dispersion residual =  4.435774677920865e-16
# dispersion residual =  4.363877600524678e-17
# An exception occurred
# dispersion residual =  1.7046349357228533e-15
# dispersion residual =  1.1922755995674048e-15
# dispersion residual =  1.0887406016544254e-15
# dispersion residual =  3.2320135682596727e-16
# dispersion residual =  1.4518268647026568e-15
# dispersion residual =  1.5725464907286445e-15
# dispersion residual =  1.4099130273282215e-15
# dispersion residual =  4.1269948214902743e-16
# dispersion residual =  1.7608614153797382e-15
# dispersion residual =  3.2335729985830213e-16
# dispersion residual =  7.209912289000769e-16
# dispersion residual =  8.571091021887599e-16
# dispersion residual =  2.927188709430491e-16
# dispersion residual =  4.4165646213940594e-17
# An exception occurred
# dispersion residual =  2.423339495048923e-15
# dispersion residual =  1.7865670121279116e-16
# dispersion residual =  1.3154635883692932e-15
# dispersion residual =  8.941408699072702e-16
# dispersion residual =  1.2453513995907709e-15
# dispersion residual =  6.848334490389733e-16
# dispersion residual =  9.763174678096836e-17
# dispersion residual =  2.3520081079361897e-15
# dispersion residual =  9.293053558582958e-16
# dispersion residual =  5.971066218670498e-16
# dispersion residual =  3.7529812074455774e-16
# dispersion residual =  1.249450379141158e-15
# dispersion residual =  5.464951006528039e-16
# dispersion residual =  1.3698358022640168e-15

# %%
fig, ax = plt.subplots(figsize=(6, 3))
pos = ax.contourf(k_perp_ii*rhoe, k_par_ii*rhoe, sol_ii.real.T / wLH)
cbar = fig.colorbar(pos)
cbar.ax.set_ylabel(r'$\frac{\omega_{r}}{|\Omega_{LH}|}$', labelpad=20, rotation=0, fontsize=20)
ax.set_xlabel(r'$k_{\perp}\rho_{e}$', fontsize=15)
ax.set_ylabel(r'$k_{\|}\rho_{e}$', fontsize=15)
#ax.set_xticks([180, 200, 220, 240])
#ax.set_xlim(175, 245)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.grid(alpha=0.5)
plt.tight_layout()
#plt.savefig("../../figs/vadim_2021/vadim_fig5_a.png", dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(6, 3))
pos = ax.contourf(k_perp_ii*rhoe, k_par_ii*rhoe, sol_ii.imag.T / wLH, vmin=1E-5, vmax=0.2, levels=np.linspace(1e-5, 0.2, 25))
cbar = fig.colorbar(pos)
cbar.ax.set_ylabel(r'$\frac{\gamma}{|\Omega_{LH}|}$', labelpad=20, rotation=0, fontsize=20)
ax.set_ylabel(r'$k_{\|}\rho_{e}$', fontsize=15)
ax.set_xlabel(r'$k_{\perp}\rho_{e}$', fontsize=15)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.grid(alpha=0.5)
plt.tight_layout()
#plt.savefig("../../figs/vadim_2021/vadim_fig5_a.png", dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(6, 3))
ax.plot(k_perp_ii*alpha_c_perp/np.sqrt(2), sol_ii.real[:, 0] / wLH)
ax.plot(k_perp_ii*alpha_c_perp/np.sqrt(2), k_perp_ii* UDO)

# %% [markdown]
# # MTSI

# %% [markdown]
# \begin{equation*}
#     k_{\perp} = \frac{\omega_{\mathrm{LH}} \sqrt{c_{cp}}}{U_{x, Dp}} \qquad \mathrm{and} \qquad \omega_{r} = \frac{1}{2^{\frac{4}{3}}} \left[\frac{m_{p}}{m_{e}} \sqrt{c_{cp}}\cos^2(\theta_{k})\right]^{\frac{1}{3}} \omega_{\mathrm{LH}}.
# \end{equation*}

# %%
# quick check
k_perp = wLH * np.sqrt(npC) / UDp   # d_e
k_par = k_perp * 1e-1
omega_guess = 1/(2**(3/4)) * ((mp_me * np.sqrt(npC)*((k_par**2)/(k_perp**2)))**(1/3)) *wLH # Omega_ce

sol_approx = scipy.optimize.newton(disp_k_(k_perp=k_perp, k_par=k_par), 
                                   omega_guess + 0.005j, tol=1e-16,
                                   maxiter=1000,
                                   x1=omega_guess * 1.2 + 1e-2j)
print(sol_approx)
print("k_perp rho_{e}", k_perp*alpha_c_perp/np.sqrt(2))
print("omega_k + i gamma = ", sol_approx * np.sqrt(mp_me))
print("dispersion residual approx = ", abs(disp_k_(k_perp=k_perp, k_par=k_par)(sol_approx)) )
# Out:
# (0.05647540734066568+0.012086759737538824j)
# k_perp rho_{e} 0.5477236180257785
# omega_k + i gamma =  (0.5647540734066568+0.12086759737538824j)
# dispersion residual approx =  7.516498169669505e-15

# %%
k_perp_mtsi = np.linspace(0.02, 5, 30) * wLH * np.sqrt(npC) / UDp # d_e
k_par_mtsi = np.linspace(0.0, 1, 20) * wLH * np.sqrt(npC) / UDp # d_e
sol_mtsi = np.ones((len(k_perp_mtsi), len(k_par_mtsi)), dtype="complex128") * np.nan

# %%
for ii in range(len(k_perp_mtsi)):
    for jj in range(len(k_par_mtsi)):
        try:
            sol_mtsi[ii, jj] = scipy.optimize.newton(disp_k_(k_perp=k_perp_mtsi[ii], k_par=k_par_mtsi[jj]),  
                                                     omega_guess + 0.005j, 
                                                 tol=1e-16, maxiter=1000, x1=omega_guess*1.2 + 1e-2j)
            error = abs(disp_k_(k_perp=k_perp_mtsi[ii], k_par=k_par_mtsi[jj])(sol_mtsi[ii, jj]))
            print("dispersion residual = ", error)
            if error > 1e-8:
                sol_mtsi[ii, jj] = np.nan
        except:
            print("An exception occurred")
# Out:
# dispersion residual =  3.66073270319803e-12
# dispersion residual =  9.144845878239056e-13
# dispersion residual =  2.901527461974926e-15
# dispersion residual =  5.071159398897968e-14
# dispersion residual =  1.1045821478188157e-13
# dispersion residual =  9.114803314567998e-16
# dispersion residual =  5.685470367124012e-12
# dispersion residual =  2.8297434717810145e-13
# dispersion residual =  2.3342525202583517e-13
# An exception occurred
# dispersion residual =  3.8444138534393106e-14
# An exception occurred
# dispersion residual =  4.474126505496146e-12
# An exception occurred
# An exception occurred
# dispersion residual =  1.4671199176124395e-12
# An exception occurred
# dispersion residual =  7.820197869955477e-13
# An exception occurred
# An exception occurred
# dispersion residual =  8.111993277798483e-13
# dispersion residual =  3.4083199994778196e-15
# dispersion residual =  6.087886059989097e-14
# dispersion residual =
# /var/folders/tt/hgb4_vc13z77x5wpt5lzk5j40000gn/T/ipykernel_19245/875342221.py:2: RuntimeWarning: invalid value encountered in scalar divide
# dispersion residual =  4.984455109556528
# An exception occurred
# /var/folders/tt/hgb4_vc13z77x5wpt5lzk5j40000gn/T/ipykernel_19245/875342221.py:2: RuntimeWarning: overflow encountered in scalar power
#   return - (k_par_**2)/(k_par_**2 + k_perp_**2) * (omega_pe_**2)/(omega**2) + omega_pe_**2 * (k_perp_**2)/(k_par_**2 + k_perp_**2)
# /var/folders/tt/hgb4_vc13z77x5wpt5lzk5j40000gn/T/ipykernel_19245/875342221.py:2: RuntimeWarning: invalid value encountered in scalar power
#   return - (k_par_**2)/(k_par_**2 + k_perp_**2) * (omega_pe_**2)/(omega**2) + omega_pe_**2 * (k_perp_**2)/(k_par_**2 + k_perp_**2)
# An exception occurred
# dispersion residual =  1.1982683229864189e-15
# dispersion residual =  7.897674153997054e-16
# dispersion residual =  2.667158658642596e-16
# dispersion residual =  1.7088700636076484e-15
# dispersion residual =  1.3648501178468796e-15
# dispersion residual =  2.069432332554994e-15
# dispersion residual =  2.359398252182338e-16
# dispersion residual =  2.314063814729121e-16
# dispersion residual =  1.6544835743086135e-15
# dispersion residual =  1.8405779958679e-15
# dispersion residual =  3.8897162617205965e-16
# dispersion residual =  4.85564768281437e-16
# dispersion residual =  1.7503279370195286e-15
# dispersion residual =  3.493558802041452e-15
# dispersion residual =  3.7293213103846013e-16
# dispersion residual =  5.191222317141477e-16
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# dispersion residual =  3.8774597972939367e-16
# dispersion residual =  1.7719156209850713e-15
# dispersion residual =  1.7912481815979525e-15
# dispersion residual =  2.260419667744646e-15
# dispersion residual =  7.509604538149719e-16
# dispersion residual =  1.143134078138567e-15
# dispersion residual =  2.8400477503960797e-16
# dispersion residual =  1.1359107922539166e-15
# dispersion residual =  4.672702295994495e-16
# dispersion residual =  5.006017868233285e-16
# dispersion residual =  5.690123081177136e-16
# dispersion residual =  5.599968305676673e-16
# dispersion residual =  6.171253454845904e-16
# dispersion residual =  1.796355742712225e-16
# dispersion residual =  3.577368024144699e-15
# dispersion residual =  9.919175101098714e-16
# An exception occurred
# An exception occurred
# An exception occurred
# dispersion residual =  4.496573455082671
# dispersion residual =  1.6285277442922343e-16
# dispersion residual =  1.0128839182184069e-16
# dispersion residual =  4.0613486283393416e-16
# dispersion residual =  5.820223363176327e-16
# dispersion residual =  2.0359623616036375e-15
# dispersion residual =  1.776406633279064e-15
# dispersion residual =  6.75812110491456e-16
# dispersion residual =  1.0435351464282858e-15
# dispersion residual =  1.6699388327840855e-15
# dispersion residual =  6.869024718788796e-16
# dispersion residual =  6.533060381826789e-16
# dispersion residual =  1.178723904247923e-15
# dispersion residual =  2.3211566555989614e-15
# dispersion residual =  9.264875133845675e-16
# dispersion residual =  5.390798502146173e-16
# dispersion residual =  8.319022593266922e-16
# An exception occurred
# An exception occurred
# An exception occurred
# dispersion residual =  4.637292496705376
# An exception occurred
# dispersion residual =  1.3312894990962966e-15
# dispersion residual =  4.522565853017996e-16
# dispersion residual =  2.6311127809840406e-16
# dispersion residual =  4.945127812191592e-16
# dispersion residual =  1.599261215751143e-15
# dispersion residual =  1.3709742078466416e-15
# dispersion residual =  1.539095471634341e-15
# dispersion residual =  1.398748777686921e-15
# dispersion residual =  4.2723755270239436e-15
# dispersion residual =  3.658484355998834e-16
# dispersion residual =  6.749165974886696e-16
# dispersion residual =  1.7713663985312083e-15
# dispersion residual =  1.6766814964039897e-16
# dispersion residual =  2.942848167056303e-16
# dispersion residual =  2.670684419939881e-15
# An exception occurred
# dispersion residual =  1.2954243221549564e-15
# An exception occurred
# An exception occurred
# An exception occurred
# dispersion residual =  1.321531307305188e-15
# dispersion residual =  2.949191361008713e-16
# dispersion residual =  1.3950932650295211e-15
# dispersion residual =  5.298046679583471e-16
# dispersion residual =  4.579693220921647e-16
# dispersion residual =  1.5743167857854689e-15
# dispersion residual =  2.3653313712052618e-15
# dispersion residual =  8.422510580431358e-16
# dispersion residual =  1.4623543929757646e-15
# dispersion residual =  1.0812980705787916e-15
# dispersion residual =  1.1782477516218242e-16
# dispersion residual =  1.8820268971547946e-16
# dispersion residual =  2.487389075035243e-16
# dispersion residual =  3.764719865357408e-15
# dispersion residual =  5.244602925617223e-16

# %%
fig, ax = plt.subplots(figsize=(6, 3))
pos = ax.contourf(k_perp_mtsi*rhoe, k_par_mtsi*rhoe, sol_mtsi.real.T /wLH, 
                  vmin=1e-5, vmax=2, levels=np.linspace(1e-2, 2, 15))
cbar = fig.colorbar(pos)
cbar.ax.set_ylabel(r'$\frac{\omega_{r}}{|\Omega_{LH}|}$', labelpad=20, rotation=0, fontsize=20)
ax.set_ylabel(r'$k_{\|}\rho_{e}$', fontsize=15)
ax.set_xlabel(r'$k_{\perp}\rho_{e}$', fontsize=15)
cbar.set_ticks([0.1, 0.5, 0.9, 1.3,  1.7])

#ax.set_xticks([180, 200, 220, 240])
#ax.set_xlim(175, 245)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.grid(alpha=0.5)
plt.tight_layout()
# plt.savefig("figures/linear_theory/MTSI/omega_r_VD_" + str(round(UDp/alpha_p_par, 1)) + "_mpme_" + str(round(mp_me))+ ".png", dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(6, 3))


pos_ii = ax.contourf(k_perp_ii*rhoe, k_par_ii*rhoe, sol_ii.imag.T / wLH,
                  vmin=1E-5,  vmax=0.4, levels=np.linspace(1e-5, 0.4, 15))

pos_mtsi = ax.contourf(k_perp_mtsi*alpha_c_perp/np.sqrt(2), k_par_mtsi*alpha_c_perp/np.sqrt(2),
                sol_mtsi.imag.T * np.sqrt(mp_me), vmin=1E-5, vmax=0.4, levels=np.linspace(1e-5, 0.4, 15))

cbar = fig.colorbar(pos_mtsi)
cbar.ax.set_ylabel(r'$\frac{\gamma}{|\Omega_{LH}|}$', labelpad=20, rotation=0, fontsize=20)
ax.set_ylabel(r'$k_{\|}\rho_{e}$', fontsize=15)
ax.set_xlabel(r'$k_{\perp}\rho_{e}$', fontsize=15)
cbar.set_ticks([1e-5, 0.1, 0.2])
cbar.set_ticklabels(["$10^{-5}$", "0.1", "0.2"])

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.grid(alpha=0.5)
plt.tight_layout()

# plt.savefig("figures/linear_theory/MTSI/gamma_VD_" + str(round(UDp/alpha_p_par, 1))  + "_mpme_" + str(round(mp_me))+ ".png", dpi=300, bbox_inches='tight')
